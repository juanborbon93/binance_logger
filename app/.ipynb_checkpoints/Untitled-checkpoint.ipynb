# %%
import os
from binance_logger import CryptoMarket,DB
import logging
market = CryptoMarket()
db = DB()

# %%
market.update_pairs_klines()

# %%
market.pairs.get("BTCUSDT").kline
# Out:
# [Kline(openTime=1616289360000, open=58378.0, high=58418.39, low=58350.05, close=58386.64, volume=39.251379, closeTime=1616289419999, quoteAssetVolume=2292192.53427713, numberOfTrades=974, takerBuyBaseAssetVolume=22.160675, takerBuyQuoteAssetVolume=1294086.46354944, Ignore=0.0),
#  Kline(openTime=1616289420000, open=58391.46, high=58425.44, low=58391.46, close=58425.03, volume=12.888093, closeTime=1616289479999, quoteAssetVolume=752780.33468617, numberOfTrades=859, takerBuyBaseAssetVolume=5.840754, takerBuyQuoteAssetVolume=341155.97470289, Ignore=0.0),
#  Kline(openTime=1616289480000, open=58419.98, high=58432.83, low=58381.45, close=58431.57, volume=18.499125, closeTime=1616289539999, quoteAssetVolume=1080616.37124308, numberOfTrades=833, takerBuyBaseAssetVolume=13.385063, takerBuyQuoteAssetVolume=781886.52287015, Ignore=0.0),
#  Kline(openTime=1616289540000, open=58425.22, high=58439.13, low=58412.13, close=58430.83, volume=10.254133, closeTime=1616289599999, quoteAssetVolume=599108.98884004, numberOfTrades=756, takerBuyBaseAssetVolume=5.20778, takerBuyQuoteAssetVolume=304276.66544751, Ignore=0.0),
#  Kline(openTime=1616289600000, open=58432.28, high=58463.99, low=58423.01, close=58433.08, volume=16.139798, closeTime=1616289659999, quoteAssetVolume=943298.52802614, numberOfTrades=820, takerBuyBaseAssetVolume=7.423358, takerBuyQuoteAssetVolume=433856.53003673, Ignore=0.0),
#  Kline(openTime=1616289660000, open=58433.08, high=58439.77, low=58433.08, close=58434.56, volume=1.836217, closeTime=1616289719999, quoteAssetVolume=107302.01043211, numberOfTrades=227, takerBuyBaseAssetVolume=0.906685, takerBuyQuoteAssetVolume=52982.98727704, Ignore=0.0)]

# %%
def record_kline_data(self,db,bucket_name):
    points = []
    for pair in self.pairs.values():
        if isinstance(pair.kline,list) and len(pair.kline)>0:
            pair_dict = pair.dict()
            tags = {key:val for key,val in pair_dict.items() if key not in ["price","kline"]}
            for k in pair.kline:
                point = {
                    "measurement":"kline",
                    "tags":tags,
                    "fields":{key:val for key,val in k.dict().items() if key not in ["openTime","closeTime"]},
                    "time":k.closeTime
                }
                points.append(point)
    db._write_client.write(bucket_name,db.org,points,'ms')

# %%
market.pairs
# Out:
# {'ETHBTC': Pair(symbol='ETHBTC', baseAsset='ETH', quoteAsset='BTC', price=Price(bidPrice=0.030945, bidQty=16.846, askPrice=0.030946, askQty=16.266), kline=None),
#  'LTCBTC': Pair(symbol='LTCBTC', baseAsset='LTC', quoteAsset='BTC', price=Price(bidPrice=0.003421, bidQty=27.31, askPrice=0.003423, askQty=193.82), kline=None),
#  'BNBBTC': Pair(symbol='BNBBTC', baseAsset='BNB', quoteAsset='BTC', price=Price(bidPrice=0.0045547, bidQty=8.39, askPrice=0.0045549, askQty=0.88), kline=None),
#  'NEOBTC': Pair(symbol='NEOBTC', baseAsset='NEO', quoteAsset='BTC', price=Price(bidPrice=0.000738, bidQty=1050.85, askPrice=0.000739, askQty=815.25), kline=None),
#  'QTUMETH': Pair(symbol='QTUMETH', baseAsset='QTUM', quoteAsset='ETH', price=Price(bidPrice=0.003709, bidQty=262.34, askPrice=0.003722, askQty=6.55), kline=None),
#  'EOSETH': Pair(symbol='EOSETH', baseAsset='EOS', quoteAsset='ETH', price=Price(bidPrice=0.002421, bidQty=1598.33, askPrice=0.002424, askQty=850.0), kline=None),
#  'SNTETH': Pair(symbol='SNTETH', baseAsset='SNT', quoteAsset='ETH', price=Price(bidPrice=5.891e-05, bidQty=107.0, askPrice=5.929e-05, askQty=159.0), kline=None),
#  'BNTETH': Pair(symbol='BNTETH', baseAsset='BNT', quoteAsset='ETH', price=Price(bidPrice=0.004543, bidQty=2063.02, askPrice=0.004559, askQty=5.65), kline=None),
#  'BCCBTC': Pair(symbol='BCCBTC', baseAsset='BCC', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'GASBTC': Pair(symbol='GASBTC', baseAsset='GAS', quoteAsset='BTC', price=Price(bidPrice=0.0001998, bidQty=30.57, askPrice=0.0002004, askQty=18.63), kline=None),
#  'BNBETH': Pair(symbol='BNBETH', baseAsset='BNB', quoteAsset='ETH', price=Price(bidPrice=0.147125, bidQty=0.3, askPrice=0.14718, askQty=9.82), kline=None),
#  'BTCUSDT': Pair(symbol='BTCUSDT', baseAsset='BTC', quoteAsset='USDT', price=Price(bidPrice=58291.6, bidQty=0.000631, askPrice=58291.61, askQty=0.470958), kline=Kline(openTime=1616288400000, open=58331.42, high=58331.43, low=58250.0, close=58254.28, volume=29.06706, closeTime=1616288459999, quoteAssetVolume=1694207.79115757, numberOfTrades=722, takerBuyBaseAssetVolume=11.751417, takerBuyQuoteAssetVolume=684972.02837943, Ignore=0.0)),
#  'ETHUSDT': Pair(symbol='ETHUSDT', baseAsset='ETH', quoteAsset='USDT', price=Price(bidPrice=1803.99, bidQty=2.95779, askPrice=1804.0, askQty=4.72049), kline=Kline(openTime=1616288400000, open=1804.27, high=1804.49, low=1797.99, close=1798.25, volume=1239.2075, closeTime=1616288459999, quoteAssetVolume=2230641.5362264, numberOfTrades=967, takerBuyBaseAssetVolume=296.33726, takerBuyQuoteAssetVolume=533211.2282621, Ignore=0.0)),
#  'HSRBTC': Pair(symbol='HSRBTC', baseAsset='HSR', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'OAXETH': Pair(symbol='OAXETH', baseAsset='OAX', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'DNTETH': Pair(symbol='DNTETH', baseAsset='DNT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MCOETH': Pair(symbol='MCOETH', baseAsset='MCO', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ICNETH': Pair(symbol='ICNETH', baseAsset='ICN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MCOBTC': Pair(symbol='MCOBTC', baseAsset='MCO', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WTCBTC': Pair(symbol='WTCBTC', baseAsset='WTC', quoteAsset='BTC', price=Price(bidPrice=2.67e-05, bidQty=1825.48, askPrice=2.68e-05, askQty=7660.16), kline=None),
#  'WTCETH': Pair(symbol='WTCETH', baseAsset='WTC', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LRCBTC': Pair(symbol='LRCBTC', baseAsset='LRC', quoteAsset='BTC', price=Price(bidPrice=9.89e-06, bidQty=8396.0, askPrice=9.9e-06, askQty=14335.0), kline=None),
#  'LRCETH': Pair(symbol='LRCETH', baseAsset='LRC', quoteAsset='ETH', price=Price(bidPrice=0.00031978, bidQty=859.0, askPrice=0.00031999, askQty=18.0), kline=None),
#  'QTUMBTC': Pair(symbol='QTUMBTC', baseAsset='QTUM', quoteAsset='BTC', price=Price(bidPrice=0.000115, bidQty=140.0, askPrice=0.0001151, askQty=1696.66), kline=None),
#  'YOYOBTC': Pair(symbol='YOYOBTC', baseAsset='YOYO', quoteAsset='BTC', price=Price(bidPrice=6.5e-07, bidQty=269177.0, askPrice=6.6e-07, askQty=112931.0), kline=None),
#  'OMGBTC': Pair(symbol='OMGBTC', baseAsset='OMG', quoteAsset='BTC', price=Price(bidPrice=9.69e-05, bidQty=17.88, askPrice=9.7e-05, askQty=5058.98), kline=None),
#  'OMGETH': Pair(symbol='OMGETH', baseAsset='OMG', quoteAsset='ETH', price=Price(bidPrice=0.003128, bidQty=91.06, askPrice=0.003133, askQty=7.35), kline=None),
#  'ZRXBTC': Pair(symbol='ZRXBTC', baseAsset='ZRX', quoteAsset='BTC', price=Price(bidPrice=2.592e-05, bidQty=992.0, askPrice=2.595e-05, askQty=374.0), kline=None),
#  'ZRXETH': Pair(symbol='ZRXETH', baseAsset='ZRX', quoteAsset='ETH', price=Price(bidPrice=0.00083756, bidQty=992.0, askPrice=0.00083895, askQty=992.0), kline=None),
#  'STRATBTC': Pair(symbol='STRATBTC', baseAsset='STRAT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'STRATETH': Pair(symbol='STRATETH', baseAsset='STRAT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'SNGLSBTC': Pair(symbol='SNGLSBTC', baseAsset='SNGLS', quoteAsset='BTC', price=Price(bidPrice=4.4e-07, bidQty=3683912.0, askPrice=4.5e-07, askQty=306614.0), kline=None),
#  'SNGLSETH': Pair(symbol='SNGLSETH', baseAsset='SNGLS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BQXBTC': Pair(symbol='BQXBTC', baseAsset='BQX', quoteAsset='BTC', price=Price(bidPrice=7.912e-05, bidQty=4.0, askPrice=7.938e-05, askQty=4356.0), kline=None),
#  'BQXETH': Pair(symbol='BQXETH', baseAsset='BQX', quoteAsset='ETH', price=Price(bidPrice=0.0025579, bidQty=10.0, askPrice=0.0025783, askQty=111.0), kline=None),
#  'KNCBTC': Pair(symbol='KNCBTC', baseAsset='KNC', quoteAsset='BTC', price=Price(bidPrice=4.718e-05, bidQty=419.0, askPrice=4.722e-05, askQty=71.0), kline=None),
#  'KNCETH': Pair(symbol='KNCETH', baseAsset='KNC', quoteAsset='ETH', price=Price(bidPrice=0.0015207, bidQty=850.0, askPrice=0.001529, askQty=28.0), kline=None),
#  'FUNBTC': Pair(symbol='FUNBTC', baseAsset='FUN', quoteAsset='BTC', price=Price(bidPrice=6.5e-07, bidQty=979871.0, askPrice=6.6e-07, askQty=5039667.0), kline=None),
#  'FUNETH': Pair(symbol='FUNETH', baseAsset='FUN', quoteAsset='ETH', price=Price(bidPrice=2.106e-05, bidQty=75122.0, askPrice=2.124e-05, askQty=20411.0), kline=None),
#  'SNMBTC': Pair(symbol='SNMBTC', baseAsset='SNM', quoteAsset='BTC', price=Price(bidPrice=7.4e-07, bidQty=2134.0, askPrice=7.5e-07, askQty=468278.0), kline=None),
#  'SNMETH': Pair(symbol='SNMETH', baseAsset='SNM', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NEOETH': Pair(symbol='NEOETH', baseAsset='NEO', quoteAsset='ETH', price=Price(bidPrice=0.023845, bidQty=10.46, askPrice=0.023875, askQty=403.42), kline=None),
#  'IOTABTC': Pair(symbol='IOTABTC', baseAsset='IOTA', quoteAsset='BTC', price=Price(bidPrice=2.388e-05, bidQty=171.0, askPrice=2.39e-05, askQty=1243.0), kline=None),
#  'IOTAETH': Pair(symbol='IOTAETH', baseAsset='IOTA', quoteAsset='ETH', price=Price(bidPrice=0.00077156, bidQty=21.0, askPrice=0.00077686, askQty=335.0), kline=None),
#  'LINKBTC': Pair(symbol='LINKBTC', baseAsset='LINK', quoteAsset='BTC', price=Price(bidPrice=0.00050907, bidQty=34.1, askPrice=0.00050914, askQty=109.0), kline=None),
#  'LINKETH': Pair(symbol='LINKETH', baseAsset='LINK', quoteAsset='ETH', price=Price(bidPrice=0.016441, bidQty=69.38, askPrice=0.016464, askQty=18.04), kline=None),
#  'XVGBTC': Pair(symbol='XVGBTC', baseAsset='XVG', quoteAsset='BTC', price=Price(bidPrice=5.8e-07, bidQty=15608962.0, askPrice=5.9e-07, askQty=1733660.0), kline=None),
#  'XVGETH': Pair(symbol='XVGETH', baseAsset='XVG', quoteAsset='ETH', price=Price(bidPrice=1.891e-05, bidQty=4649.0, askPrice=1.901e-05, askQty=1631.0), kline=None),
#  'SALTBTC': Pair(symbol='SALTBTC', baseAsset='SALT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'SALTETH': Pair(symbol='SALTETH', baseAsset='SALT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MDABTC': Pair(symbol='MDABTC', baseAsset='MDA', quoteAsset='BTC', price=Price(bidPrice=2.401e-05, bidQty=117.0, askPrice=2.405e-05, askQty=3862.0), kline=None),
#  'MDAETH': Pair(symbol='MDAETH', baseAsset='MDA', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MTLBTC': Pair(symbol='MTLBTC', baseAsset='MTL', quoteAsset='BTC', price=Price(bidPrice=2.526e-05, bidQty=4.0, askPrice=2.528e-05, askQty=20.0), kline=None),
#  'MTLETH': Pair(symbol='MTLETH', baseAsset='MTL', quoteAsset='ETH', price=Price(bidPrice=0.000816, bidQty=29.18, askPrice=0.000821, askQty=46.32), kline=None),
#  'SUBBTC': Pair(symbol='SUBBTC', baseAsset='SUB', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'SUBETH': Pair(symbol='SUBETH', baseAsset='SUB', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'EOSBTC': Pair(symbol='EOSBTC', baseAsset='EOS', quoteAsset='BTC', price=Price(bidPrice=7.49e-05, bidQty=13389.43, askPrice=7.5e-05, askQty=4601.26), kline=None),
#  'SNTBTC': Pair(symbol='SNTBTC', baseAsset='SNT', quoteAsset='BTC', price=Price(bidPrice=1.82e-06, bidQty=8452.0, askPrice=1.83e-06, askQty=60710.0), kline=None),
#  'ETCETH': Pair(symbol='ETCETH', baseAsset='ETC', quoteAsset='ETH', price=Price(bidPrice=0.006825, bidQty=21.29, askPrice=0.006846, askQty=11.31), kline=None),
#  'ETCBTC': Pair(symbol='ETCBTC', baseAsset='ETC', quoteAsset='BTC', price=Price(bidPrice=0.0002115, bidQty=3.96, askPrice=0.0002116, askQty=471.91), kline=None),
#  'MTHBTC': Pair(symbol='MTHBTC', baseAsset='MTH', quoteAsset='BTC', price=Price(bidPrice=7.4e-07, bidQty=57442.0, askPrice=7.5e-07, askQty=108372.0), kline=None),
#  'MTHETH': Pair(symbol='MTHETH', baseAsset='MTH', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ENGBTC': Pair(symbol='ENGBTC', baseAsset='ENG', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ENGETH': Pair(symbol='ENGETH', baseAsset='ENG', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'DNTBTC': Pair(symbol='DNTBTC', baseAsset='DNT', quoteAsset='BTC', price=Price(bidPrice=5.62e-06, bidQty=449.0, askPrice=5.64e-06, askQty=4572.0), kline=None),
#  'ZECBTC': Pair(symbol='ZECBTC', baseAsset='ZEC', quoteAsset='BTC', price=Price(bidPrice=0.002647, bidQty=13.043, askPrice=0.002652, askQty=12.216), kline=None),
#  'ZECETH': Pair(symbol='ZECETH', baseAsset='ZEC', quoteAsset='ETH', price=Price(bidPrice=0.0855, bidQty=37.741, askPrice=0.08566, askQty=56.278), kline=None),
#  'BNTBTC': Pair(symbol='BNTBTC', baseAsset='BNT', quoteAsset='BTC', price=Price(bidPrice=0.00014081, bidQty=51.0, askPrice=0.00014097, askQty=90.7), kline=None),
#  'ASTBTC': Pair(symbol='ASTBTC', baseAsset='AST', quoteAsset='BTC', price=Price(bidPrice=8.38e-06, bidQty=582.0, askPrice=8.39e-06, askQty=882.0), kline=None),
#  'ASTETH': Pair(symbol='ASTETH', baseAsset='AST', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'DASHBTC': Pair(symbol='DASHBTC', baseAsset='DASH', quoteAsset='BTC', price=Price(bidPrice=0.003891, bidQty=15.964, askPrice=0.003895, askQty=4.901), kline=None),
#  'DASHETH': Pair(symbol='DASHETH', baseAsset='DASH', quoteAsset='ETH', price=Price(bidPrice=0.12565, bidQty=2.642, askPrice=0.12596, askQty=2.017), kline=None),
#  'OAXBTC': Pair(symbol='OAXBTC', baseAsset='OAX', quoteAsset='BTC', price=Price(bidPrice=7.38e-06, bidQty=1286.0, askPrice=7.42e-06, askQty=23229.0), kline=None),
#  'ICNBTC': Pair(symbol='ICNBTC', baseAsset='ICN', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BTGBTC': Pair(symbol='BTGBTC', baseAsset='BTG', quoteAsset='BTC', price=Price(bidPrice=0.000518, bidQty=3.69, askPrice=0.00052, askQty=15.25), kline=None),
#  'BTGETH': Pair(symbol='BTGETH', baseAsset='BTG', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'EVXBTC': Pair(symbol='EVXBTC', baseAsset='EVX', quoteAsset='BTC', price=Price(bidPrice=1.497e-05, bidQty=167.0, askPrice=1.509e-05, askQty=1363.0), kline=None),
#  'EVXETH': Pair(symbol='EVXETH', baseAsset='EVX', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'REQBTC': Pair(symbol='REQBTC', baseAsset='REQ', quoteAsset='BTC', price=Price(bidPrice=2.4e-06, bidQty=124363.0, askPrice=2.41e-06, askQty=876.0), kline=None),
#  'REQETH': Pair(symbol='REQETH', baseAsset='REQ', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VIBBTC': Pair(symbol='VIBBTC', baseAsset='VIB', quoteAsset='BTC', price=Price(bidPrice=1.47e-06, bidQty=18493.0, askPrice=1.48e-06, askQty=97063.0), kline=None),
#  'VIBETH': Pair(symbol='VIBETH', baseAsset='VIB', quoteAsset='ETH', price=Price(bidPrice=4.741e-05, bidQty=3241.0, askPrice=4.78e-05, askQty=234.0), kline=None),
#  'HSRETH': Pair(symbol='HSRETH', baseAsset='HSR', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TRXBTC': Pair(symbol='TRXBTC', baseAsset='TRX', quoteAsset='BTC', price=Price(bidPrice=1.07e-06, bidQty=90649.0, askPrice=1.08e-06, askQty=13100692.0), kline=None),
#  'TRXETH': Pair(symbol='TRXETH', baseAsset='TRX', quoteAsset='ETH', price=Price(bidPrice=3.459e-05, bidQty=205.0, askPrice=3.461e-05, askQty=80295.0), kline=None),
#  'POWRBTC': Pair(symbol='POWRBTC', baseAsset='POWR', quoteAsset='BTC', price=Price(bidPrice=6.17e-06, bidQty=5343.0, askPrice=6.19e-06, askQty=7508.0), kline=None),
#  'POWRETH': Pair(symbol='POWRETH', baseAsset='POWR', quoteAsset='ETH', price=Price(bidPrice=0.00019875, bidQty=696.0, askPrice=0.00020004, askQty=3929.0), kline=None),
#  'ARKBTC': Pair(symbol='ARKBTC', baseAsset='ARK', quoteAsset='BTC', price=Price(bidPrice=2.581e-05, bidQty=50.0, askPrice=2.591e-05, askQty=642.0), kline=None),
#  'ARKETH': Pair(symbol='ARKETH', baseAsset='ARK', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'YOYOETH': Pair(symbol='YOYOETH', baseAsset='YOYO', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XRPBTC': Pair(symbol='XRPBTC', baseAsset='XRP', quoteAsset='BTC', price=Price(bidPrice=9.05e-06, bidQty=36358.0, askPrice=9.06e-06, askQty=80443.0), kline=None),
#  'XRPETH': Pair(symbol='XRPETH', baseAsset='XRP', quoteAsset='ETH', price=Price(bidPrice=0.00029234, bidQty=5815.0, askPrice=0.00029263, askQty=14600.0), kline=None),
#  'MODBTC': Pair(symbol='MODBTC', baseAsset='MOD', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MODETH': Pair(symbol='MODETH', baseAsset='MOD', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ENJBTC': Pair(symbol='ENJBTC', baseAsset='ENJ', quoteAsset='BTC', price=Price(bidPrice=3.831e-05, bidQty=5.0, askPrice=3.832e-05, askQty=2140.0), kline=None),
#  'ENJETH': Pair(symbol='ENJETH', baseAsset='ENJ', quoteAsset='ETH', price=Price(bidPrice=0.00123736, bidQty=38.0, askPrice=0.00124222, askQty=462.0), kline=None),
#  'STORJBTC': Pair(symbol='STORJBTC', baseAsset='STORJ', quoteAsset='BTC', price=Price(bidPrice=1.538e-05, bidQty=1233.0, askPrice=1.541e-05, askQty=203.0), kline=None),
#  'STORJETH': Pair(symbol='STORJETH', baseAsset='STORJ', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BNBUSDT': Pair(symbol='BNBUSDT', baseAsset='BNB', quoteAsset='USDT', price=Price(bidPrice=265.4696, bidQty=5.874, askPrice=265.5233, askQty=3.185), kline=Kline(openTime=1616288400000, open=265.7599, high=265.7599, low=265.0581, close=265.142, volume=755.856, closeTime=1616288459999, quoteAssetVolume=200556.424616, numberOfTrades=248, takerBuyBaseAssetVolume=237.295, takerBuyQuoteAssetVolume=62942.8910689, Ignore=0.0)),
#  'VENBNB': Pair(symbol='VENBNB', baseAsset='VEN', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'YOYOBNB': Pair(symbol='YOYOBNB', baseAsset='YOYO', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'POWRBNB': Pair(symbol='POWRBNB', baseAsset='POWR', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VENBTC': Pair(symbol='VENBTC', baseAsset='VEN', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VENETH': Pair(symbol='VENETH', baseAsset='VEN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'KMDBTC': Pair(symbol='KMDBTC', baseAsset='KMD', quoteAsset='BTC', price=Price(bidPrice=2.94e-05, bidQty=10394.01, askPrice=2.95e-05, askQty=150.0), kline=None),
#  'KMDETH': Pair(symbol='KMDETH', baseAsset='KMD', quoteAsset='ETH', price=Price(bidPrice=0.000951, bidQty=17.96, askPrice=0.000955, askQty=18.44), kline=None),
#  'NULSBNB': Pair(symbol='NULSBNB', baseAsset='NULS', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RCNBTC': Pair(symbol='RCNBTC', baseAsset='RCN', quoteAsset='BTC', price=Price(bidPrice=2.09e-06, bidQty=6352.0, askPrice=2.1e-06, askQty=247812.0), kline=None),
#  'RCNETH': Pair(symbol='RCNETH', baseAsset='RCN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RCNBNB': Pair(symbol='RCNBNB', baseAsset='RCN', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NULSBTC': Pair(symbol='NULSBTC', baseAsset='NULS', quoteAsset='BTC', price=Price(bidPrice=1.553e-05, bidQty=103.0, askPrice=1.554e-05, askQty=6460.0), kline=None),
#  'NULSETH': Pair(symbol='NULSETH', baseAsset='NULS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RDNBTC': Pair(symbol='RDNBTC', baseAsset='RDN', quoteAsset='BTC', price=Price(bidPrice=1.334e-05, bidQty=148.0, askPrice=1.338e-05, askQty=11.0), kline=None),
#  'RDNETH': Pair(symbol='RDNETH', baseAsset='RDN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RDNBNB': Pair(symbol='RDNBNB', baseAsset='RDN', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XMRBTC': Pair(symbol='XMRBTC', baseAsset='XMR', quoteAsset='BTC', price=Price(bidPrice=0.003977, bidQty=4.1, askPrice=0.003978, askQty=20.6), kline=None),
#  'XMRETH': Pair(symbol='XMRETH', baseAsset='XMR', quoteAsset='ETH', price=Price(bidPrice=0.12844, bidQty=0.051, askPrice=0.1287, askQty=1.809), kline=None),
#  'DLTBNB': Pair(symbol='DLTBNB', baseAsset='DLT', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WTCBNB': Pair(symbol='WTCBNB', baseAsset='WTC', quoteAsset='BNB', price=Price(bidPrice=0.00584, bidQty=1814.7, askPrice=0.00591, askQty=12.6), kline=None),
#  'DLTBTC': Pair(symbol='DLTBTC', baseAsset='DLT', quoteAsset='BTC', price=Price(bidPrice=3.14e-06, bidQty=320.0, askPrice=3.15e-06, askQty=766.0), kline=None),
#  'DLTETH': Pair(symbol='DLTETH', baseAsset='DLT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'AMBBTC': Pair(symbol='AMBBTC', baseAsset='AMB', quoteAsset='BTC', price=Price(bidPrice=1.65e-06, bidQty=30658.0, askPrice=1.66e-06, askQty=236568.0), kline=None),
#  'AMBETH': Pair(symbol='AMBETH', baseAsset='AMB', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'AMBBNB': Pair(symbol='AMBBNB', baseAsset='AMB', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BCCETH': Pair(symbol='BCCETH', baseAsset='BCC', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BCCUSDT': Pair(symbol='BCCUSDT', baseAsset='BCC', quoteAsset='USDT', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=Kline(openTime=1542682740000, open=448.7, high=448.7, low=448.7, close=448.7, volume=0.0, closeTime=1542682799152, quoteAssetVolume=0.0, numberOfTrades=0, takerBuyBaseAssetVolume=0.0, takerBuyQuoteAssetVolume=0.0, Ignore=0.0)),
#  'BCCBNB': Pair(symbol='BCCBNB', baseAsset='BCC', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BATBTC': Pair(symbol='BATBTC', baseAsset='BAT', quoteAsset='BTC', price=Price(bidPrice=1.885e-05, bidQty=3622.0, askPrice=1.888e-05, askQty=1394.0), kline=None),
#  'BATETH': Pair(symbol='BATETH', baseAsset='BAT', quoteAsset='ETH', price=Price(bidPrice=0.00060802, bidQty=4164.0, askPrice=0.00061158, askQty=769.0), kline=None),
#  'BATBNB': Pair(symbol='BATBNB', baseAsset='BAT', quoteAsset='BNB', price=Price(bidPrice=0.00413, bidQty=6526.1, askPrice=0.00415, askQty=4381.7), kline=None),
#  'BCPTBTC': Pair(symbol='BCPTBTC', baseAsset='BCPT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BCPTETH': Pair(symbol='BCPTETH', baseAsset='BCPT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BCPTBNB': Pair(symbol='BCPTBNB', baseAsset='BCPT', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ARNBTC': Pair(symbol='ARNBTC', baseAsset='ARN', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ARNETH': Pair(symbol='ARNETH', baseAsset='ARN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'GVTBTC': Pair(symbol='GVTBTC', baseAsset='GVT', quoteAsset='BTC', price=Price(bidPrice=0.0001305, bidQty=67.15, askPrice=0.0001307, askQty=132.21), kline=None),
#  'GVTETH': Pair(symbol='GVTETH', baseAsset='GVT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CDTBTC': Pair(symbol='CDTBTC', baseAsset='CDT', quoteAsset='BTC', price=Price(bidPrice=6.2e-07, bidQty=3306275.0, askPrice=6.3e-07, askQty=389478.0), kline=None),
#  'CDTETH': Pair(symbol='CDTETH', baseAsset='CDT', quoteAsset='ETH', price=Price(bidPrice=2.017e-05, bidQty=503.0, askPrice=2.02e-05, askQty=1867.0), kline=None),
#  'GXSBTC': Pair(symbol='GXSBTC', baseAsset='GXS', quoteAsset='BTC', price=Price(bidPrice=1.333e-05, bidQty=49.0, askPrice=1.335e-05, askQty=357.0), kline=None),
#  'GXSETH': Pair(symbol='GXSETH', baseAsset='GXS', quoteAsset='ETH', price=Price(bidPrice=0.00043, bidQty=26.31, askPrice=0.000432, askQty=149.64), kline=None),
#  'NEOUSDT': Pair(symbol='NEOUSDT', baseAsset='NEO', quoteAsset='USDT', price=Price(bidPrice=43.033, bidQty=47.064, askPrice=43.057, askQty=20.54), kline=Kline(openTime=1616288400000, open=43.053, high=43.053, low=42.9, close=42.9, volume=2277.786, closeTime=1616288459999, quoteAssetVolume=97960.715065, numberOfTrades=185, takerBuyBaseAssetVolume=82.163, takerBuyQuoteAssetVolume=3531.921253, Ignore=0.0)),
#  'NEOBNB': Pair(symbol='NEOBNB', baseAsset='NEO', quoteAsset='BNB', price=Price(bidPrice=0.162, bidQty=116.02, askPrice=0.1623, askQty=40.47), kline=None),
#  'POEBTC': Pair(symbol='POEBTC', baseAsset='POE', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'POEETH': Pair(symbol='POEETH', baseAsset='POE', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'QSPBTC': Pair(symbol='QSPBTC', baseAsset='QSP', quoteAsset='BTC', price=Price(bidPrice=1.65e-06, bidQty=4708.0, askPrice=1.66e-06, askQty=132716.0), kline=None),
#  'QSPETH': Pair(symbol='QSPETH', baseAsset='QSP', quoteAsset='ETH', price=Price(bidPrice=5.34e-05, bidQty=1000.0, askPrice=5.394e-05, askQty=6980.0), kline=None),
#  'QSPBNB': Pair(symbol='QSPBNB', baseAsset='QSP', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BTSBTC': Pair(symbol='BTSBTC', baseAsset='BTS', quoteAsset='BTC', price=Price(bidPrice=1.33e-06, bidQty=553524.0, askPrice=1.34e-06, askQty=153204.0), kline=None),
#  'BTSETH': Pair(symbol='BTSETH', baseAsset='BTS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BTSBNB': Pair(symbol='BTSBNB', baseAsset='BTS', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XZCBTC': Pair(symbol='XZCBTC', baseAsset='XZC', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XZCETH': Pair(symbol='XZCETH', baseAsset='XZC', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XZCBNB': Pair(symbol='XZCBNB', baseAsset='XZC', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LSKBTC': Pair(symbol='LSKBTC', baseAsset='LSK', quoteAsset='BTC', price=Price(bidPrice=6.78e-05, bidQty=1786.46, askPrice=6.8e-05, askQty=420.92), kline=None),
#  'LSKETH': Pair(symbol='LSKETH', baseAsset='LSK', quoteAsset='ETH', price=Price(bidPrice=0.002191, bidQty=11.29, askPrice=0.002199, askQty=29.79), kline=None),
#  'LSKBNB': Pair(symbol='LSKBNB', baseAsset='LSK', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TNTBTC': Pair(symbol='TNTBTC', baseAsset='TNT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TNTETH': Pair(symbol='TNTETH', baseAsset='TNT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'FUELBTC': Pair(symbol='FUELBTC', baseAsset='FUEL', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'FUELETH': Pair(symbol='FUELETH', baseAsset='FUEL', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MANABTC': Pair(symbol='MANABTC', baseAsset='MANA', quoteAsset='BTC', price=Price(bidPrice=1.555e-05, bidQty=5637.0, askPrice=1.556e-05, askQty=1246.0), kline=None),
#  'MANAETH': Pair(symbol='MANAETH', baseAsset='MANA', quoteAsset='ETH', price=Price(bidPrice=0.00050239, bidQty=68.0, askPrice=0.0005048, askQty=3197.0), kline=None),
#  'BCDBTC': Pair(symbol='BCDBTC', baseAsset='BCD', quoteAsset='BTC', price=Price(bidPrice=1.981e-05, bidQty=4.0, askPrice=1.988e-05, askQty=533.0), kline=None),
#  'BCDETH': Pair(symbol='BCDETH', baseAsset='BCD', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'DGDBTC': Pair(symbol='DGDBTC', baseAsset='DGD', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'DGDETH': Pair(symbol='DGDETH', baseAsset='DGD', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'IOTABNB': Pair(symbol='IOTABNB', baseAsset='IOTA', quoteAsset='BNB', price=Price(bidPrice=0.00524, bidQty=236.2, askPrice=0.00526, askQty=4803.5), kline=None),
#  'ADXBTC': Pair(symbol='ADXBTC', baseAsset='ADX', quoteAsset='BTC', price=Price(bidPrice=1.914e-05, bidQty=3578.0, askPrice=1.919e-05, askQty=11851.0), kline=None),
#  'ADXETH': Pair(symbol='ADXETH', baseAsset='ADX', quoteAsset='ETH', price=Price(bidPrice=0.0006177, bidQty=404.0, askPrice=0.0006233, askQty=46.0), kline=None),
#  'ADXBNB': Pair(symbol='ADXBNB', baseAsset='ADX', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ADABTC': Pair(symbol='ADABTC', baseAsset='ADA', quoteAsset='BTC', price=Price(bidPrice=2.091e-05, bidQty=36255.0, askPrice=2.093e-05, askQty=14360.0), kline=None),
#  'ADAETH': Pair(symbol='ADAETH', baseAsset='ADA', quoteAsset='ETH', price=Price(bidPrice=0.00067566, bidQty=2060.0, askPrice=0.00067655, askQty=174.0), kline=None),
#  'PPTBTC': Pair(symbol='PPTBTC', baseAsset='PPT', quoteAsset='BTC', price=Price(bidPrice=5.27e-05, bidQty=89.0, askPrice=5.299e-05, askQty=353.0), kline=None),
#  'PPTETH': Pair(symbol='PPTETH', baseAsset='PPT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CMTBTC': Pair(symbol='CMTBTC', baseAsset='CMT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CMTETH': Pair(symbol='CMTETH', baseAsset='CMT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CMTBNB': Pair(symbol='CMTBNB', baseAsset='CMT', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'XLMBTC': Pair(symbol='XLMBTC', baseAsset='XLM', quoteAsset='BTC', price=Price(bidPrice=7.11e-06, bidQty=29875.0, askPrice=7.12e-06, askQty=49588.0), kline=None),
#  'XLMETH': Pair(symbol='XLMETH', baseAsset='XLM', quoteAsset='ETH', price=Price(bidPrice=0.00022983, bidQty=242.0, askPrice=0.00023014, askQty=3955.0), kline=None),
#  'XLMBNB': Pair(symbol='XLMBNB', baseAsset='XLM', quoteAsset='BNB', price=Price(bidPrice=0.001561, bidQty=3241.0, askPrice=0.001565, askQty=18091.0), kline=None),
#  'CNDBTC': Pair(symbol='CNDBTC', baseAsset='CND', quoteAsset='BTC', price=Price(bidPrice=6.4e-07, bidQty=1006627.0, askPrice=6.5e-07, askQty=1372762.0), kline=None),
#  'CNDETH': Pair(symbol='CNDETH', baseAsset='CND', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CNDBNB': Pair(symbol='CNDBNB', baseAsset='CND', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LENDBTC': Pair(symbol='LENDBTC', baseAsset='LEND', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LENDETH': Pair(symbol='LENDETH', baseAsset='LEND', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WABIBTC': Pair(symbol='WABIBTC', baseAsset='WABI', quoteAsset='BTC', price=Price(bidPrice=6.54e-06, bidQty=17402.0, askPrice=6.58e-06, askQty=31471.0), kline=None),
#  'WABIETH': Pair(symbol='WABIETH', baseAsset='WABI', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WABIBNB': Pair(symbol='WABIBNB', baseAsset='WABI', quoteAsset='BNB', price=Price(bidPrice=0.001441, bidQty=569.0, askPrice=0.001462, askQty=801.0), kline=None),
#  'LTCETH': Pair(symbol='LTCETH', baseAsset='LTC', quoteAsset='ETH', price=Price(bidPrice=0.11051, bidQty=0.717, askPrice=0.11061, askQty=31.723), kline=None),
#  'LTCUSDT': Pair(symbol='LTCUSDT', baseAsset='LTC', quoteAsset='USDT', price=Price(bidPrice=199.47, bidQty=12.60007, askPrice=199.51, askQty=2.74794), kline=Kline(openTime=1616288400000, open=199.63, high=199.63, low=199.36, close=199.41, volume=223.17288, closeTime=1616288459999, quoteAssetVolume=44524.2096314, numberOfTrades=100, takerBuyBaseAssetVolume=25.7102, takerBuyQuoteAssetVolume=5127.6035533, Ignore=0.0)),
#  'LTCBNB': Pair(symbol='LTCBNB', baseAsset='LTC', quoteAsset='BNB', price=Price(bidPrice=0.75, bidQty=17.093, askPrice=0.752, askQty=15.136), kline=None),
#  'TNBBTC': Pair(symbol='TNBBTC', baseAsset='TNB', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TNBETH': Pair(symbol='TNBETH', baseAsset='TNB', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WAVESBTC': Pair(symbol='WAVESBTC', baseAsset='WAVES', quoteAsset='BTC', price=Price(bidPrice=0.0001735, bidQty=35.47, askPrice=0.0001737, askQty=62.68), kline=None),
#  'WAVESETH': Pair(symbol='WAVESETH', baseAsset='WAVES', quoteAsset='ETH', price=Price(bidPrice=0.005602, bidQty=4.76, askPrice=0.005624, askQty=191.4), kline=None),
#  'WAVESBNB': Pair(symbol='WAVESBNB', baseAsset='WAVES', quoteAsset='BNB', price=Price(bidPrice=0.03802, bidQty=580.8, askPrice=0.0383, askQty=532.1), kline=None),
#  'GTOBTC': Pair(symbol='GTOBTC', baseAsset='GTO', quoteAsset='BTC', price=Price(bidPrice=7.3e-07, bidQty=1479791.0, askPrice=7.4e-07, askQty=311734.0), kline=None),
#  'GTOETH': Pair(symbol='GTOETH', baseAsset='GTO', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'GTOBNB': Pair(symbol='GTOBNB', baseAsset='GTO', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ICXBTC': Pair(symbol='ICXBTC', baseAsset='ICX', quoteAsset='BTC', price=Price(bidPrice=3.306e-05, bidQty=7.0, askPrice=3.309e-05, askQty=1093.0), kline=None),
#  'ICXETH': Pair(symbol='ICXETH', baseAsset='ICX', quoteAsset='ETH', price=Price(bidPrice=0.001067, bidQty=255.43, askPrice=0.00107, askQty=26.03), kline=None),
#  'ICXBNB': Pair(symbol='ICXBNB', baseAsset='ICX', quoteAsset='BNB', price=Price(bidPrice=0.00726, bidQty=82.6, askPrice=0.00728, askQty=36.4), kline=None),
#  'OSTBTC': Pair(symbol='OSTBTC', baseAsset='OST', quoteAsset='BTC', price=Price(bidPrice=5.5e-07, bidQty=13512.0, askPrice=5.6e-07, askQty=2161890.0), kline=None),
#  'OSTETH': Pair(symbol='OSTETH', baseAsset='OST', quoteAsset='ETH', price=Price(bidPrice=1.764e-05, bidQty=13512.0, askPrice=1.781e-05, askQty=2831.0), kline=None),
#  'OSTBNB': Pair(symbol='OSTBNB', baseAsset='OST', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ELFBTC': Pair(symbol='ELFBTC', baseAsset='ELF', quoteAsset='BTC', price=Price(bidPrice=5.66e-06, bidQty=5751.0, askPrice=5.68e-06, askQty=1828.0), kline=None),
#  'ELFETH': Pair(symbol='ELFETH', baseAsset='ELF', quoteAsset='ETH', price=Price(bidPrice=0.00018311, bidQty=307.0, askPrice=0.00018337, askQty=431.0), kline=None),
#  'AIONBTC': Pair(symbol='AIONBTC', baseAsset='AION', quoteAsset='BTC', price=Price(bidPrice=4.37e-06, bidQty=2345.0, askPrice=4.39e-06, askQty=12313.0), kline=None),
#  'AIONETH': Pair(symbol='AIONETH', baseAsset='AION', quoteAsset='ETH', price=Price(bidPrice=0.000141, bidQty=906.64, askPrice=0.000142, askQty=24242.37), kline=None),
#  'AIONBNB': Pair(symbol='AIONBNB', baseAsset='AION', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NEBLBTC': Pair(symbol='NEBLBTC', baseAsset='NEBL', quoteAsset='BTC', price=Price(bidPrice=4.285e-05, bidQty=24.0, askPrice=4.307e-05, askQty=17.0), kline=None),
#  'NEBLETH': Pair(symbol='NEBLETH', baseAsset='NEBL', quoteAsset='ETH', price=Price(bidPrice=0.00138, bidQty=59.0, askPrice=0.001392, askQty=48.46), kline=None),
#  'NEBLBNB': Pair(symbol='NEBLBNB', baseAsset='NEBL', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BRDBTC': Pair(symbol='BRDBTC', baseAsset='BRD', quoteAsset='BTC', price=Price(bidPrice=5.37e-06, bidQty=50.0, askPrice=5.39e-06, askQty=69197.0), kline=None),
#  'BRDETH': Pair(symbol='BRDETH', baseAsset='BRD', quoteAsset='ETH', price=Price(bidPrice=0.000173, bidQty=100.0, askPrice=0.000174, askQty=329.0), kline=None),
#  'BRDBNB': Pair(symbol='BRDBNB', baseAsset='BRD', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'MCOBNB': Pair(symbol='MCOBNB', baseAsset='MCO', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'EDOBTC': Pair(symbol='EDOBTC', baseAsset='EDO', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'EDOETH': Pair(symbol='EDOETH', baseAsset='EDO', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WINGSBTC': Pair(symbol='WINGSBTC', baseAsset='WINGS', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WINGSETH': Pair(symbol='WINGSETH', baseAsset='WINGS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NAVBTC': Pair(symbol='NAVBTC', baseAsset='NAV', quoteAsset='BTC', price=Price(bidPrice=1.678e-05, bidQty=1000.0, askPrice=1.683e-05, askQty=5999.0), kline=None),
#  'NAVETH': Pair(symbol='NAVETH', baseAsset='NAV', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NAVBNB': Pair(symbol='NAVBNB', baseAsset='NAV', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LUNBTC': Pair(symbol='LUNBTC', baseAsset='LUN', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'LUNETH': Pair(symbol='LUNETH', baseAsset='LUN', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TRIGBTC': Pair(symbol='TRIGBTC', baseAsset='TRIG', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TRIGETH': Pair(symbol='TRIGETH', baseAsset='TRIG', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TRIGBNB': Pair(symbol='TRIGBNB', baseAsset='TRIG', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'APPCBTC': Pair(symbol='APPCBTC', baseAsset='APPC', quoteAsset='BTC', price=Price(bidPrice=2.24e-06, bidQty=25312.0, askPrice=2.25e-06, askQty=6170.0), kline=None),
#  'APPCETH': Pair(symbol='APPCETH', baseAsset='APPC', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'APPCBNB': Pair(symbol='APPCBNB', baseAsset='APPC', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VIBEBTC': Pair(symbol='VIBEBTC', baseAsset='VIBE', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VIBEETH': Pair(symbol='VIBEETH', baseAsset='VIBE', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RLCBTC': Pair(symbol='RLCBTC', baseAsset='RLC', quoteAsset='BTC', price=Price(bidPrice=3.763e-05, bidQty=87.0, askPrice=3.77e-05, askQty=54.0), kline=None),
#  'RLCETH': Pair(symbol='RLCETH', baseAsset='RLC', quoteAsset='ETH', price=Price(bidPrice=0.001215, bidQty=121.67, askPrice=0.001219, askQty=18.37), kline=None),
#  'RLCBNB': Pair(symbol='RLCBNB', baseAsset='RLC', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'INSBTC': Pair(symbol='INSBTC', baseAsset='INS', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'INSETH': Pair(symbol='INSETH', baseAsset='INS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'PIVXBTC': Pair(symbol='PIVXBTC', baseAsset='PIVX', quoteAsset='BTC', price=Price(bidPrice=2.11e-05, bidQty=4315.0, askPrice=2.113e-05, askQty=433.0), kline=None),
#  'PIVXETH': Pair(symbol='PIVXETH', baseAsset='PIVX', quoteAsset='ETH', price=Price(bidPrice=0.000679, bidQty=368.18, askPrice=0.000685, askQty=163.84), kline=None),
#  'PIVXBNB': Pair(symbol='PIVXBNB', baseAsset='PIVX', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'IOSTBTC': Pair(symbol='IOSTBTC', baseAsset='IOST', quoteAsset='BTC', price=Price(bidPrice=1.01e-06, bidQty=8224352.0, askPrice=1.02e-06, askQty=9284640.0), kline=None),
#  'IOSTETH': Pair(symbol='IOSTETH', baseAsset='IOST', quoteAsset='ETH', price=Price(bidPrice=3.272e-05, bidQty=20781.0, askPrice=3.283e-05, askQty=8381.0), kline=None),
#  'CHATBTC': Pair(symbol='CHATBTC', baseAsset='CHAT', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'CHATETH': Pair(symbol='CHATETH', baseAsset='CHAT', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'STEEMBTC': Pair(symbol='STEEMBTC', baseAsset='STEEM', quoteAsset='BTC', price=Price(bidPrice=9.54e-06, bidQty=109.0, askPrice=9.55e-06, askQty=1171.0), kline=None),
#  'STEEMETH': Pair(symbol='STEEMETH', baseAsset='STEEM', quoteAsset='ETH', price=Price(bidPrice=0.000306, bidQty=1585.21, askPrice=0.000309, askQty=3944.16), kline=None),
#  'STEEMBNB': Pair(symbol='STEEMBNB', baseAsset='STEEM', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NANOBTC': Pair(symbol='NANOBTC', baseAsset='NANO', quoteAsset='BTC', price=Price(bidPrice=8.71e-05, bidQty=73.0, askPrice=8.73e-05, askQty=2765.15), kline=None),
#  'NANOETH': Pair(symbol='NANOETH', baseAsset='NANO', quoteAsset='ETH', price=Price(bidPrice=0.002815, bidQty=2.33, askPrice=0.002823, askQty=7.54), kline=None),
#  'NANOBNB': Pair(symbol='NANOBNB', baseAsset='NANO', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VIABTC': Pair(symbol='VIABTC', baseAsset='VIA', quoteAsset='BTC', price=Price(bidPrice=1.506e-05, bidQty=184.0, askPrice=1.509e-05, askQty=43.0), kline=None),
#  'VIAETH': Pair(symbol='VIAETH', baseAsset='VIA', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'VIABNB': Pair(symbol='VIABNB', baseAsset='VIA', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BLZBTC': Pair(symbol='BLZBTC', baseAsset='BLZ', quoteAsset='BTC', price=Price(bidPrice=6.32e-06, bidQty=4210.0, askPrice=6.34e-06, askQty=10861.0), kline=None),
#  'BLZETH': Pair(symbol='BLZETH', baseAsset='BLZ', quoteAsset='ETH', price=Price(bidPrice=0.00020376, bidQty=27036.0, askPrice=0.00020491, askQty=29.0), kline=None),
#  'BLZBNB': Pair(symbol='BLZBNB', baseAsset='BLZ', quoteAsset='BNB', price=Price(bidPrice=0.001385, bidQty=27323.0, askPrice=0.001393, askQty=13.0), kline=None),
#  'AEBTC': Pair(symbol='AEBTC', baseAsset='AE', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'AEETH': Pair(symbol='AEETH', baseAsset='AE', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'AEBNB': Pair(symbol='AEBNB', baseAsset='AE', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RPXBTC': Pair(symbol='RPXBTC', baseAsset='RPX', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RPXETH': Pair(symbol='RPXETH', baseAsset='RPX', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'RPXBNB': Pair(symbol='RPXBNB', baseAsset='RPX', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NCASHBTC': Pair(symbol='NCASHBTC', baseAsset='NCASH', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'NCASHETH': Pair(symbol='NCASHETH', baseAsset='NCASH', quoteAsset='ETH', price=Price(bidPrice=2.57e-06, bidQty=262986.0, askPrice=2.59e-06, askQty=52349.0), kline=None),
#  'NCASHBNB': Pair(symbol='NCASHBNB', baseAsset='NCASH', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'POABTC': Pair(symbol='POABTC', baseAsset='POA', quoteAsset='BTC', price=Price(bidPrice=1.64e-06, bidQty=10113.0, askPrice=1.65e-06, askQty=26488.0), kline=None),
#  'POAETH': Pair(symbol='POAETH', baseAsset='POA', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'POABNB': Pair(symbol='POABNB', baseAsset='POA', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'ZILBTC': Pair(symbol='ZILBTC', baseAsset='ZIL', quoteAsset='BTC', price=Price(bidPrice=2.95e-06, bidQty=26675.0, askPrice=2.96e-06, askQty=331765.0), kline=None),
#  'ZILETH': Pair(symbol='ZILETH', baseAsset='ZIL', quoteAsset='ETH', price=Price(bidPrice=9.533e-05, bidQty=2971.0, askPrice=9.556e-05, askQty=64.0), kline=None),
#  'ZILBNB': Pair(symbol='ZILBNB', baseAsset='ZIL', quoteAsset='BNB', price=Price(bidPrice=0.0006475, bidQty=2488.0, askPrice=0.0006495, askQty=16394.0), kline=None),
#  'ONTBTC': Pair(symbol='ONTBTC', baseAsset='ONT', quoteAsset='BTC', price=Price(bidPrice=2.05e-05, bidQty=338.31, askPrice=2.06e-05, askQty=36354.98), kline=None),
#  'ONTETH': Pair(symbol='ONTETH', baseAsset='ONT', quoteAsset='ETH', price=Price(bidPrice=0.000662, bidQty=8172.9, askPrice=0.000663, askQty=34.69), kline=None),
#  'ONTBNB': Pair(symbol='ONTBNB', baseAsset='ONT', quoteAsset='BNB', price=Price(bidPrice=0.0045, bidQty=925.1, askPrice=0.00451, askQty=49.7), kline=None),
#  'STORMBTC': Pair(symbol='STORMBTC', baseAsset='STORM', quoteAsset='BTC', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'STORMETH': Pair(symbol='STORMETH', baseAsset='STORM', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'STORMBNB': Pair(symbol='STORMBNB', baseAsset='STORM', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'QTUMBNB': Pair(symbol='QTUMBNB', baseAsset='QTUM', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'QTUMUSDT': Pair(symbol='QTUMUSDT', baseAsset='QTUM', quoteAsset='USDT', price=Price(bidPrice=6.705, bidQty=43.414, askPrice=6.707, askQty=200.0), kline=Kline(openTime=1616288400000, open=6.698, high=6.698, low=6.675, close=6.683, volume=1786.696, closeTime=1616288459999, quoteAssetVolume=11938.899604, numberOfTrades=54, takerBuyBaseAssetVolume=588.969, takerBuyQuoteAssetVolume=3936.084237, Ignore=0.0)),
#  'XEMBTC': Pair(symbol='XEMBTC', baseAsset='XEM', quoteAsset='BTC', price=Price(bidPrice=6.29e-06, bidQty=14936.0, askPrice=6.3e-06, askQty=27935.0), kline=None),
#  'XEMETH': Pair(symbol='XEMETH', baseAsset='XEM', quoteAsset='ETH', price=Price(bidPrice=0.00020314, bidQty=8114.0, askPrice=0.00020396, askQty=54.0), kline=None),
#  'XEMBNB': Pair(symbol='XEMBNB', baseAsset='XEM', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WANBTC': Pair(symbol='WANBTC', baseAsset='WAN', quoteAsset='BTC', price=Price(bidPrice=2.124e-05, bidQty=6.0, askPrice=2.133e-05, askQty=320.0), kline=None),
#  'WANETH': Pair(symbol='WANETH', baseAsset='WAN', quoteAsset='ETH', price=Price(bidPrice=0.000686, bidQty=27.52, askPrice=0.000688, askQty=16.15), kline=None),
#  'WANBNB': Pair(symbol='WANBNB', baseAsset='WAN', quoteAsset='BNB', price=Price(bidPrice=0.00466, bidQty=706.3, askPrice=0.00468, askQty=16.1), kline=None),
#  'WPRBTC': Pair(symbol='WPRBTC', baseAsset='WPR', quoteAsset='BTC', price=Price(bidPrice=6.9e-07, bidQty=1187392.0, askPrice=7e-07, askQty=39976.0), kline=None),
#  'WPRETH': Pair(symbol='WPRETH', baseAsset='WPR', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'QLCBTC': Pair(symbol='QLCBTC', baseAsset='QLC', quoteAsset='BTC', price=Price(bidPrice=2.08e-06, bidQty=21076.0, askPrice=2.09e-06, askQty=23834.0), kline=None),
#  'QLCETH': Pair(symbol='QLCETH', baseAsset='QLC', quoteAsset='ETH', price=Price(bidPrice=6.715e-05, bidQty=124.0, askPrice=6.752e-05, askQty=124.0), kline=None),
#  'SYSBTC': Pair(symbol='SYSBTC', baseAsset='SYS', quoteAsset='BTC', price=Price(bidPrice=5.41e-06, bidQty=337.0, askPrice=5.42e-06, askQty=1453.0), kline=None),
#  'SYSETH': Pair(symbol='SYSETH', baseAsset='SYS', quoteAsset='ETH', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'SYSBNB': Pair(symbol='SYSBNB', baseAsset='SYS', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'QLCBNB': Pair(symbol='QLCBNB', baseAsset='QLC', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
# ...
#  'KMDUSDT': Pair(symbol='KMDUSDT', baseAsset='KMD', quoteAsset='USDT', price=Price(bidPrice=1.719, bidQty=0.09, askPrice=1.7295, askQty=37.29), kline=Kline(openTime=1616288400000, open=1.7146, high=1.7146, low=1.7146, close=1.7146, volume=0.0, closeTime=1616288459999, quoteAssetVolume=0.0, numberOfTrades=0, takerBuyBaseAssetVolume=0.0, takerBuyQuoteAssetVolume=0.0, Ignore=0.0)),
#  'BTCDAI': Pair(symbol='BTCDAI', baseAsset='BTC', quoteAsset='DAI', price=Price(bidPrice=58168.43, bidQty=0.052482, askPrice=58249.27, askQty=0.02069), kline=None),
#  'ETHDAI': Pair(symbol='ETHDAI', baseAsset='ETH', quoteAsset='DAI', price=Price(bidPrice=1801.37, bidQty=0.72105, askPrice=1802.68, askQty=6.9), kline=None),
#  'BNBDAI': Pair(symbol='BNBDAI', baseAsset='BNB', quoteAsset='DAI', price=Price(bidPrice=264.872, bidQty=7.545, askPrice=265.305, askQty=0.242), kline=None),
#  'USDTDAI': Pair(symbol='USDTDAI', baseAsset='USDT', quoteAsset='DAI', price=Price(bidPrice=0.9987, bidQty=23336.32, askPrice=0.9988, askQty=3546.71), kline=None),
#  'BUSDDAI': Pair(symbol='BUSDDAI', baseAsset='BUSD', quoteAsset='DAI', price=Price(bidPrice=0.9987, bidQty=75.16, askPrice=0.9988, askQty=43404.38), kline=None),
#  'JSTBNB': Pair(symbol='JSTBNB', baseAsset='JST', quoteAsset='BNB', price=Price(bidPrice=0.000391, bidQty=69721.0, askPrice=0.000393, askQty=21724.0), kline=None),
#  'JSTBTC': Pair(symbol='JSTBTC', baseAsset='JST', quoteAsset='BTC', price=Price(bidPrice=1.78e-06, bidQty=74563.0, askPrice=1.79e-06, askQty=95712.0), kline=None),
#  'JSTBUSD': Pair(symbol='JSTBUSD', baseAsset='JST', quoteAsset='BUSD', price=Price(bidPrice=0.10383, bidQty=126.4, askPrice=0.10437, askQty=3670.5), kline=None),
#  'JSTUSDT': Pair(symbol='JSTUSDT', baseAsset='JST', quoteAsset='USDT', price=Price(bidPrice=0.10399, bidQty=3435.9, askPrice=0.1041, askQty=12667.6), kline=Kline(openTime=1616288400000, open=0.10435, high=0.10435, low=0.10304, close=0.10342, volume=576429.9, closeTime=1616288459999, quoteAssetVolume=59809.783987, numberOfTrades=125, takerBuyBaseAssetVolume=122950.9, takerBuyQuoteAssetVolume=12731.847081, Ignore=0.0)),
#  'SRMBNB': Pair(symbol='SRMBNB', baseAsset='SRM', quoteAsset='BNB', price=Price(bidPrice=0.019016, bidQty=8.0, askPrice=0.019079, askQty=13.0), kline=None),
#  'SRMBTC': Pair(symbol='SRMBTC', baseAsset='SRM', quoteAsset='BTC', price=Price(bidPrice=8.666e-05, bidQty=58.0, askPrice=8.679e-05, askQty=9.0), kline=None),
#  'SRMBUSD': Pair(symbol='SRMBUSD', baseAsset='SRM', quoteAsset='BUSD', price=Price(bidPrice=5.054, bidQty=59.02, askPrice=5.063, askQty=2.76), kline=None),
#  'SRMUSDT': Pair(symbol='SRMUSDT', baseAsset='SRM', quoteAsset='USDT', price=Price(bidPrice=5.0571, bidQty=186.07, askPrice=5.0588, askQty=132.0), kline=Kline(openTime=1616288400000, open=5.0569, high=5.0569, low=5.01, close=5.0185, volume=7492.48, closeTime=1616288459999, quoteAssetVolume=37714.394859, numberOfTrades=205, takerBuyBaseAssetVolume=1828.76, takerBuyQuoteAssetVolume=9189.48012, Ignore=0.0)),
#  'ANTBNB': Pair(symbol='ANTBNB', baseAsset='ANT', quoteAsset='BNB', price=Price(bidPrice=0.0269, bidQty=1012.03, askPrice=0.0271, askQty=268.26), kline=None),
#  'ANTBTC': Pair(symbol='ANTBTC', baseAsset='ANT', quoteAsset='BTC', price=Price(bidPrice=0.0001229, bidQty=227.73, askPrice=0.0001231, askQty=11.03), kline=None),
#  'ANTBUSD': Pair(symbol='ANTBUSD', baseAsset='ANT', quoteAsset='BUSD', price=Price(bidPrice=7.1701, bidQty=1.95, askPrice=7.1817, askQty=17.12), kline=None),
#  'ANTUSDT': Pair(symbol='ANTUSDT', baseAsset='ANT', quoteAsset='USDT', price=Price(bidPrice=7.1661, bidQty=77.68, askPrice=7.1768, askQty=9.37), kline=Kline(openTime=1616288400000, open=7.1406, high=7.1414, low=7.1406, close=7.1406, volume=43.03, closeTime=1616288459999, quoteAssetVolume=307.28205, numberOfTrades=3, takerBuyBaseAssetVolume=0.0, takerBuyQuoteAssetVolume=0.0, Ignore=0.0)),
#  'CRVBNB': Pair(symbol='CRVBNB', baseAsset='CRV', quoteAsset='BNB', price=Price(bidPrice=0.0101, bidQty=12871.58, askPrice=0.0103, askQty=4798.89), kline=None),
#  'CRVBTC': Pair(symbol='CRVBTC', baseAsset='CRV', quoteAsset='BTC', price=Price(bidPrice=4.64e-05, bidQty=161.0, askPrice=4.65e-05, askQty=3983.1), kline=None),
#  'CRVBUSD': Pair(symbol='CRVBUSD', baseAsset='CRV', quoteAsset='BUSD', price=Price(bidPrice=2.703, bidQty=688.264, askPrice=2.709, askQty=13.883), kline=None),
#  'CRVUSDT': Pair(symbol='CRVUSDT', baseAsset='CRV', quoteAsset='USDT', price=Price(bidPrice=2.706, bidQty=147.397, askPrice=2.708, askQty=1157.4), kline=Kline(openTime=1616288400000, open=2.704, high=2.706, low=2.698, close=2.706, volume=5247.191, closeTime=1616288459999, quoteAssetVolume=14176.904964, numberOfTrades=37, takerBuyBaseAssetVolume=1710.579, takerBuyQuoteAssetVolume=4626.631083, Ignore=0.0)),
#  'SANDBNB': Pair(symbol='SANDBNB', baseAsset='SAND', quoteAsset='BNB', price=Price(bidPrice=0.002091, bidQty=113.0, askPrice=0.0020959, askQty=80.0), kline=None),
#  'SANDBTC': Pair(symbol='SANDBTC', baseAsset='SAND', quoteAsset='BTC', price=Price(bidPrice=9.52e-06, bidQty=3440.0, askPrice=9.54e-06, askQty=647.0), kline=None),
#  'SANDUSDT': Pair(symbol='SANDUSDT', baseAsset='SAND', quoteAsset='USDT', price=Price(bidPrice=0.555377, bidQty=712.0, askPrice=0.555737, askQty=3769.0), kline=Kline(openTime=1616288400000, open=0.555561, high=0.555561, low=0.5536, close=0.554944, volume=76668.0, closeTime=1616288459999, quoteAssetVolume=42504.840627, numberOfTrades=100, takerBuyBaseAssetVolume=24881.0, takerBuyQuoteAssetVolume=13795.973634, Ignore=0.0)),
#  'SANDBUSD': Pair(symbol='SANDBUSD', baseAsset='SAND', quoteAsset='BUSD', price=Price(bidPrice=0.554451, bidQty=150.0, askPrice=0.557321, askQty=60.0), kline=None),
#  'OCEANBNB': Pair(symbol='OCEANBNB', baseAsset='OCEAN', quoteAsset='BNB', price=Price(bidPrice=0.0056, bidQty=16467.8, askPrice=0.00563, askQty=219.5), kline=None),
#  'OCEANBTC': Pair(symbol='OCEANBTC', baseAsset='OCEAN', quoteAsset='BTC', price=Price(bidPrice=2.554e-05, bidQty=41.0, askPrice=2.557e-05, askQty=285.0), kline=None),
#  'OCEANBUSD': Pair(symbol='OCEANBUSD', baseAsset='OCEAN', quoteAsset='BUSD', price=Price(bidPrice=1.4892, bidQty=320.55, askPrice=1.4969, askQty=13.42), kline=None),
#  'OCEANUSDT': Pair(symbol='OCEANUSDT', baseAsset='OCEAN', quoteAsset='USDT', price=Price(bidPrice=1.4886, bidQty=13669.02, askPrice=1.4901, askQty=835.0), kline=Kline(openTime=1616288400000, open=1.49, high=1.4904, low=1.484, close=1.4858, volume=19641.62, closeTime=1616288459999, quoteAssetVolume=29220.970829, numberOfTrades=48, takerBuyBaseAssetVolume=1644.75, takerBuyQuoteAssetVolume=2443.857537, Ignore=0.0)),
#  'NMRBNB': Pair(symbol='NMRBNB', baseAsset='NMR', quoteAsset='BNB', price=Price(bidPrice=0.1929, bidQty=2.79, askPrice=0.1946, askQty=10.86), kline=None),
#  'NMRBTC': Pair(symbol='NMRBTC', baseAsset='NMR', quoteAsset='BTC', price=Price(bidPrice=0.000878, bidQty=82.445, askPrice=0.00088, askQty=0.396), kline=None),
#  'NMRBUSD': Pair(symbol='NMRBUSD', baseAsset='NMR', quoteAsset='BUSD', price=Price(bidPrice=51.221, bidQty=0.222, askPrice=51.267, askQty=1.0), kline=None),
#  'NMRUSDT': Pair(symbol='NMRUSDT', baseAsset='NMR', quoteAsset='USDT', price=Price(bidPrice=51.098, bidQty=0.477, askPrice=51.267, askQty=0.209), kline=Kline(openTime=1616288400000, open=51.038, high=51.038, low=51.038, close=51.038, volume=0.0, closeTime=1616288459999, quoteAssetVolume=0.0, numberOfTrades=0, takerBuyBaseAssetVolume=0.0, takerBuyQuoteAssetVolume=0.0, Ignore=0.0)),
#  'DOTBNB': Pair(symbol='DOTBNB', baseAsset='DOT', quoteAsset='BNB', price=Price(bidPrice=0.14207, bidQty=3.6, askPrice=0.14221, askQty=0.5), kline=None),
#  'DOTBTC': Pair(symbol='DOTBTC', baseAsset='DOT', quoteAsset='BTC', price=Price(bidPrice=0.00064676, bidQty=38.0, askPrice=0.00064718, askQty=38.0), kline=None),
#  'DOTBUSD': Pair(symbol='DOTBUSD', baseAsset='DOT', quoteAsset='BUSD', price=Price(bidPrice=37.7057, bidQty=59.6, askPrice=37.7394, askQty=77.9), kline=None),
#  'DOTUSDT': Pair(symbol='DOTUSDT', baseAsset='DOT', quoteAsset='USDT', price=Price(bidPrice=37.7102, bidQty=0.04, askPrice=37.7229, askQty=135.0), kline=Kline(openTime=1616288400000, open=37.686, high=37.686, low=37.57, close=37.5943, volume=2678.15, closeTime=1616288459999, quoteAssetVolume=100727.305353, numberOfTrades=190, takerBuyBaseAssetVolume=738.97, takerBuyQuoteAssetVolume=27789.609868, Ignore=0.0)),
#  'LUNABNB': Pair(symbol='LUNABNB', baseAsset='LUNA', quoteAsset='BNB', price=Price(bidPrice=0.08084, bidQty=1.3, askPrice=0.081, askQty=342.4), kline=None),
#  'LUNABTC': Pair(symbol='LUNABTC', baseAsset='LUNA', quoteAsset='BTC', price=Price(bidPrice=0.00036851, bidQty=5.5, askPrice=0.00036871, askQty=2.1), kline=None),
#  'LUNABUSD': Pair(symbol='LUNABUSD', baseAsset='LUNA', quoteAsset='BUSD', price=Price(bidPrice=21.4729, bidQty=52.67, askPrice=21.5156, askQty=87.23), kline=None),
#  'LUNAUSDT': Pair(symbol='LUNAUSDT', baseAsset='LUNA', quoteAsset='USDT', price=Price(bidPrice=21.4832, bidQty=58.29, askPrice=21.4895, askQty=81.0), kline=Kline(openTime=1616288400000, open=21.5449, high=21.5449, low=21.4418, close=21.4489, volume=6041.5, closeTime=1616288459999, quoteAssetVolume=129785.620444, numberOfTrades=152, takerBuyBaseAssetVolume=1000.95, takerBuyQuoteAssetVolume=21501.656663, Ignore=0.0)),
#  'IDEXBTC': Pair(symbol='IDEXBTC', baseAsset='IDEX', quoteAsset='BTC', price=Price(bidPrice=1.69e-06, bidQty=84450.0, askPrice=1.7e-06, askQty=9066.0), kline=None),
#  'IDEXBUSD': Pair(symbol='IDEXBUSD', baseAsset='IDEX', quoteAsset='BUSD', price=Price(bidPrice=0.09903, bidQty=1761.0, askPrice=0.09927, askQty=995.5), kline=None),
#  'RSRBNB': Pair(symbol='RSRBNB', baseAsset='RSR', quoteAsset='BNB', price=Price(bidPrice=0.000333, bidQty=441.0, askPrice=0.000334, askQty=23137.0), kline=None),
#  'RSRBTC': Pair(symbol='RSRBTC', baseAsset='RSR', quoteAsset='BTC', price=Price(bidPrice=1.51e-06, bidQty=1493207.0, askPrice=1.52e-06, askQty=161556.0), kline=None),
#  'RSRBUSD': Pair(symbol='RSRBUSD', baseAsset='RSR', quoteAsset='BUSD', price=Price(bidPrice=0.08851, bidQty=125.1, askPrice=0.08876, askQty=851.7), kline=None),
#  'RSRUSDT': Pair(symbol='RSRUSDT', baseAsset='RSR', quoteAsset='USDT', price=Price(bidPrice=0.08849, bidQty=7290.2, askPrice=0.08857, askQty=24226.0), kline=Kline(openTime=1616288400000, open=0.08835, high=0.08837, low=0.08809, close=0.08829, volume=295536.5, closeTime=1616288459999, quoteAssetVolume=26057.497509, numberOfTrades=68, takerBuyBaseAssetVolume=240215.9, takerBuyQuoteAssetVolume=21175.020393, Ignore=0.0)),
#  'PAXGBNB': Pair(symbol='PAXGBNB', baseAsset='PAXG', quoteAsset='BNB', price=Price(bidPrice=6.606, bidQty=0.342, askPrice=6.617, askQty=0.308), kline=None),
#  'PAXGBTC': Pair(symbol='PAXGBTC', baseAsset='PAXG', quoteAsset='BTC', price=Price(bidPrice=0.0301, bidQty=0.03, askPrice=0.03012, askQty=0.0336), kline=None),
#  'PAXGBUSD': Pair(symbol='PAXGBUSD', baseAsset='PAXG', quoteAsset='BUSD', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'PAXGUSDT': Pair(symbol='PAXGUSDT', baseAsset='PAXG', quoteAsset='USDT', price=Price(bidPrice=1754.79, bidQty=0.27638, askPrice=1755.54, askQty=0.03324), kline=Kline(openTime=1616288400000, open=1754.79, high=1756.89, low=1754.29, close=1756.89, volume=1.467418, closeTime=1616288459999, quoteAssetVolume=2575.78564935, numberOfTrades=24, takerBuyBaseAssetVolume=0.902746, takerBuyQuoteAssetVolume=1585.16789473, Ignore=0.0)),
#  'WNXMBNB': Pair(symbol='WNXMBNB', baseAsset='WNXM', quoteAsset='BNB', price=Price(bidPrice=0.18, bidQty=16.118, askPrice=0.181, askQty=0.556), kline=None),
#  'WNXMBTC': Pair(symbol='WNXMBTC', baseAsset='WNXM', quoteAsset='BTC', price=Price(bidPrice=0.000821, bidQty=24.832, askPrice=0.000823, askQty=6.04), kline=None),
#  'WNXMBUSD': Pair(symbol='WNXMBUSD', baseAsset='WNXM', quoteAsset='BUSD', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'WNXMUSDT': Pair(symbol='WNXMUSDT', baseAsset='WNXM', quoteAsset='USDT', price=Price(bidPrice=47.946, bidQty=4.035, askPrice=48.005, askQty=0.945), kline=Kline(openTime=1616288400000, open=47.946, high=47.946, low=47.902, close=47.902, volume=5.508, closeTime=1616288459999, quoteAssetVolume=264.025256, numberOfTrades=4, takerBuyBaseAssetVolume=0.0, takerBuyQuoteAssetVolume=0.0, Ignore=0.0)),
#  'TRBBNB': Pair(symbol='TRBBNB', baseAsset='TRB', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'TRBBTC': Pair(symbol='TRBBTC', baseAsset='TRB', quoteAsset='BTC', price=Price(bidPrice=0.000848, bidQty=87.58, askPrice=0.00085, askQty=35.0), kline=None),
#  'TRBBUSD': Pair(symbol='TRBBUSD', baseAsset='TRB', quoteAsset='BUSD', price=Price(bidPrice=49.41, bidQty=1.311, askPrice=49.743, askQty=0.658), kline=None),
#  'TRBUSDT': Pair(symbol='TRBUSDT', baseAsset='TRB', quoteAsset='USDT', price=Price(bidPrice=49.493, bidQty=12.563, askPrice=49.533, askQty=4.0), kline=Kline(openTime=1616288400000, open=49.497, high=49.497, low=49.3, close=49.303, volume=210.156, closeTime=1616288459999, quoteAssetVolume=10369.947392, numberOfTrades=54, takerBuyBaseAssetVolume=101.366, takerBuyQuoteAssetVolume=5002.422478, Ignore=0.0)),
#  'ETHNGN': Pair(symbol='ETHNGN', baseAsset='ETH', quoteAsset='NGN', price=Price(bidPrice=783376.0, bidQty=0.01915, askPrice=809990.0, askQty=0.02), kline=None),
#  'DOTBIDR': Pair(symbol='DOTBIDR', baseAsset='DOT', quoteAsset='BIDR', price=Price(bidPrice=550726.0, bidQty=0.005, askPrice=550727.0, askQty=9.972), kline=None),
#  'LINKAUD': Pair(symbol='LINKAUD', baseAsset='LINK', quoteAsset='AUD', price=Price(bidPrice=38.564, bidQty=10.36, askPrice=38.632, askQty=13.123), kline=None),
#  'SXPAUD': Pair(symbol='SXPAUD', baseAsset='SXP', quoteAsset='AUD', price=Price(bidPrice=4.699, bidQty=3.257, askPrice=4.711, askQty=134.963), kline=None),
#  'BZRXBNB': Pair(symbol='BZRXBNB', baseAsset='BZRX', quoteAsset='BNB', price=Price(bidPrice=0.0, bidQty=0.0, askPrice=0.0, askQty=0.0), kline=None),
#  'BZRXBTC': Pair(symbol='BZRXBTC', baseAsset='BZRX', quoteAsset='BTC', price=Price(bidPrice=9.96e-06, bidQty=1038.0, askPrice=9.99e-06, askQty=8635.0), kline=None),
#  'BZRXBUSD': Pair(symbol='BZRXBUSD', baseAsset='BZRX', quoteAsset='BUSD', price=Price(bidPrice=0.5801, bidQty=279.0, askPrice=0.5827, askQty=33.61), kline=None),
#  'BZRXUSDT': Pair(symbol='BZRXUSDT', baseAsset='BZRX', quoteAsset='USDT', price=Price(bidPrice=0.5806, bidQty=1201.17, askPrice=0.5815, askQty=1566.75), kline=Kline(openTime=1616288400000, open=0.5808, high=0.5812, low=0.58, close=0.5809, volume=3864.06, closeTime=1616288459999, quoteAssetVolume=2243.979961, numberOfTrades=15, takerBuyBaseAssetVolume=1574.67, takerBuyQuoteAssetVolume=914.676649, Ignore=0.0)),
#  'WBTCBTC': Pair(symbol='WBTCBTC', baseAsset='WBTC', quoteAsset='BTC', price=Price(bidPrice=1.00001, bidQty=0.0152, askPrice=1.00065, askQty=0.0007), kline=None),
#  'WBTCETH': Pair(symbol='WBTCETH', baseAsset='WBTC', quoteAsset='ETH', price=Price(bidPrice=32.2847, bidQty=0.0015, askPrice=32.3322, askQty=0.03), kline=None),
#  'SUSHIBNB': Pair(symbol='SUSHIBNB', baseAsset='SUSHI', quoteAsset='BNB', price=Price(bidPrice=0.0732, bidQty=9.55, askPrice=0.0733, askQty=275.98), kline=None),
#  'SUSHIBTC': Pair(symbol='SUSHIBTC', baseAsset='SUSHI', quoteAsset='BTC', price=Price(bidPrice=0.0003331, bidQty=6.19, askPrice=0.0003333, askQty=845.0), kline=None),
#  'SUSHIBUSD': Pair(symbol='SUSHIBUSD', baseAsset='SUSHI', quoteAsset='BUSD', price=Price(bidPrice=19.428, bidQty=11.7, askPrice=19.454, askQty=19.4), kline=None),
#  'SUSHIUSDT': Pair(symbol='SUSHIUSDT', baseAsset='SUSHI', quoteAsset='USDT', price=Price(bidPrice=19.426, bidQty=50.0, askPrice=19.44, askQty=568.329), kline=Kline(openTime=1616288400000, open=19.416, high=19.42, low=19.374, close=19.39, volume=2106.844, closeTime=1616288459999, quoteAssetVolume=40862.633428, numberOfTrades=96, takerBuyBaseAssetVolume=1150.544, takerBuyQuoteAssetVolume=22314.579802, Ignore=0.0)),
#  ...}
